# %%
from __future__ import division
import random
import math
import time

# %%
def func1(x):
    y = 3*(1-x[0])**2*math.exp(-x[0]**2 - (x[1]+1)**2) - 10*(x[0]/5 - x[0]**3 - x[1]**5)*math.exp(-x[0]**2 - x[1]**2) -1/3*math.exp(-(x[0]+1)**2 - x[1]**2);
    return y

# %%
import numpy as np
import math

# %%
from statistics import mean
from math import gamma

# %%
class Hawks:
    def __init__(self,bounds):
        self.hawks_position=[]
                    
        for i in range(n_dim):
            self.hawks_position.append(random.uniform(bounds[i][0],bounds[i][1]))            
            
            
            
    def evaluate(self,costFunc):
        self.fitness = costFunc(self.hawks_position)        

class HHO():            
    def __init__(self,costFunc,bounds,hawks_size,maxiter):
        global n_dim
        n_dim=len(bounds)
        rabbit_energy=float('inf')
        rabbit_pos=[]
        hawks=[]
        for i in range(0,hawks_size):
            hawks.append(Hawks(bounds))
        
        for i in range(maxiter):
            hawk_random=random.choice(hawks)
            avg=[mean(a for a,b in hawks),mean(c for c,d in hawks)]
            q=random.uniform(0,1)
            r1=random.random(0,1)
            r2=random.random(0,1)
            r3=random.random(0,1)
            r4=random.random(0,1)
            E0=random.random(-1,1)
            E=2*E0(1-((i+1)/maxiter))
            J=2*(1-random.random(0,1))
            for j in range(hawks-1):
                hawks[j].evaluate(costFunc)
                #if (rabbit_energy>hawks[j].fitness()):
                    #rabbit_energy=hawks[j].fitness()
                    #rabbit_pos=list(hawks[j].hawks_position)
                if abs(E)>=1:
                    for k in range(n_dim):
                        if q>=0.5:
                            hawks[j+1].hawks_position[k]=hawk_random[k]-(r1*hawk_random[k])-(2*r2*hawks[j].hawks_position[k])
                        else:
                            hawks[j+1].hawks_position[k]=(rabbit_pos[k]-avg[k])-r3*(bounds[k][0]+r4(bounds[k][1]-bounds[k][0]))
            
                else:
                    r=random.random(0,1)
                    for k in range(n_dim):
                        pos=rabbit_pos[k]-hawks[j].hawks_position[k]
                        if(r>=0.5):
                            if(abs(E)>=0.5):
                                hawks[j+1].hawks_position=pos-E*abs(J*rabbit_pos[k]-hawks[j].hawks_position[k])
                            else:
                                hawks[j+1].hawks_position=rabbit_pos[k]-(E*pos)
                        else:
                            xichma = pow((gamma(1 + 1.5) * math.sin(math.pi * 1.5 / 2.0)) / (gamma((1 + 1.5) * 1.5 * pow(2, (1.5 - 1) / 2)) / 2.0), 1.0 / 1.5)
                            LF_D = 0.01 * random.uniform() * xichma / pow(abs(random.uniform()), 1.0 / 1.5)
                            if(abs(E)>=0.5):
                                Y=rabbit_pos[k]-E*abs(J*rabbit_pos[k]-hawks[j].hawks_position[k])
                            else:
                                Y=rabbit_pos[k]-E*abs(J*rabbit_pos[k]-avg[k])
                            Z=Y+random.uniform(0,1)*LF_D
                            fit_Y=Y.fitness()
                            fit_Z=Z.fitness()
                            
                            if(fit_Y<hawks[j].fitness):
                                hawks[j+1]=Y
                            if(fit_Z<hawks[j].fitness):
                                hawks[j+1]=Z
                            
        print("best pos ",rabbit_pos)
        print("Fitness ",rabbit_energy )

# %%
tic = time.time()
bounds=[(-3,3),(-3,3)]  # input bounds [(x1_min,x1_max),(x2_min,x2_max)...]
HHO(func1,bounds,hawks_size=50,maxiter=100)
toc = time.time()
print(toc -tic)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-26-ab7ce0d54c85> in <module>
#       1 tic = time.time()
#       2 bounds=[(-3,3),(-3,3)]  # input bounds [(x1_min,x1_max),(x2_min,x2_max)...]
# ----> 3 HHO(func1,bounds,hawks_size=50,maxiter=100)
#       4 toc = time.time()
#       5 print(toc -tic)
#
# <ipython-input-25-d49ccf2ef023> in __init__(self, costFunc, bounds, hawks_size, maxiter)
#      23         for i in range(maxiter):
#      24             hawk_random=random.choice(hawks)
# ---> 25             avg=[mean([a for a,b in hawks]),mean([c for c,d in hawks])]
#      26             q=random.uniform(0,1)
#      27             r1=random.random(0,1)
#
# <ipython-input-25-d49ccf2ef023> in <listcomp>(.0)
#      23         for i in range(maxiter):
#      24             hawk_random=random.choice(hawks)
# ...

# %%
import random
import numpy
import math
#from solution import solution
import time

def HHO(objf,lb,ub,dim,SearchAgents_no,Max_iter):

    #dim=30
    #SearchAgents_no=50
    #lb=-100
    #ub=100
    #Max_iter=500
        
    
    # initialize the location and Energy of the rabbit
    Rabbit_Location=numpy.zeros(dim)
    Rabbit_Energy=float("inf")  #change this to -inf for maximization problems
    
    
    #Initialize the locations of Harris' hawks
    X=numpy.random.uniform(0,1,(SearchAgents_no,dim)) *(ub-lb)+lb
    
    #Initialize convergence
    convergence_curve=numpy.zeros(Max_iter)
    
    
    ############################
    #s=solution()

    print("HHO is now tackling  \""+objf.__name__+"\"")    

    timerStart=time.time() 
    #s.startTime=time.strftime("%Y-%m-%d-%H-%M-%S")
    ############################
    
    t=0  # Loop counter
    
    # Main loop
    while t<Max_iter:
        for i in range(0,SearchAgents_no):
            
            # Check boundries
                      
            X[i,:]=numpy.clip(X[i,:], lb, ub)
            
            # fitness of locations
            fitness=objf(X[i,:])
            
            # Update the location of Rabbit
            if fitness<Rabbit_Energy: # Change this to > for maximization problem
                Rabbit_Energy=fitness 
                Rabbit_Location=X[i,:].copy() 
            
        E1=2*(1-(t/Max_iter)) # factor to show the decreaing energy of rabbit    
        
        # Update the location of Harris' hawks 
        for i in range(0,SearchAgents_no):

            E0=2*random.random()-1;  # -1<E0<1
            Escaping_Energy=E1*(E0)  # escaping energy of rabbit Eq. (3) in the paper

            # -------- Exploration phase Eq. (1) in paper -------------------

            if abs(Escaping_Energy)>=1:
                #Harris' hawks perch randomly based on 2 strategy:
                q = random.random()
                rand_Hawk_index = math.floor(SearchAgents_no*random.random())
                X_rand = X[rand_Hawk_index, :]
                if q<0.5:
                    # perch based on other family members
                    X[i,:]=X_rand-random.random()*abs(X_rand-2*random.random()*X[i,:])

                elif q>=0.5:
                    #perch on a random tall tree (random site inside group's home range)
                    X[i,:]=(Rabbit_Location - X.mean(0))-random.random()*((ub-lb)*random.random()+lb)

            # -------- Exploitation phase -------------------
            elif abs(Escaping_Energy)<1:
                #Attacking the rabbit using 4 strategies regarding the behavior of the rabbit

                #phase 1: ----- surprise pounce (seven kills) ----------
                #surprise pounce (seven kills): multiple, short rapid dives by different hawks

                r=random.random() # probablity of each event
                
                if r>=0.5 and abs(Escaping_Energy)<0.5: # Hard besiege Eq. (6) in paper
                    X[i,:]=(Rabbit_Location)-Escaping_Energy*abs(Rabbit_Location-X[i,:])

                if r>=0.5 and abs(Escaping_Energy)>=0.5:  # Soft besiege Eq. (4) in paper
                    Jump_strength=2*(1- random.random()); # random jump strength of the rabbit
                    X[i,:]=(Rabbit_Location-X[i,:])-Escaping_Energy*abs(Jump_strength*Rabbit_Location-X[i,:])
                
                #phase 2: --------performing team rapid dives (leapfrog movements)----------

                if r<0.5 and abs(Escaping_Energy)>=0.5: # Soft besiege Eq. (10) in paper
                    #rabbit try to escape by many zigzag deceptive motions
                    Jump_strength=2*(1-random.random())
                    X1=Rabbit_Location-Escaping_Energy*abs(Jump_strength*Rabbit_Location-X[i,:]);

                    if objf(X1)< fitness: # improved move?
                        X[i,:] = X1.copy()
                    else: # hawks perform levy-based short rapid dives around the rabbit
                        X2=Rabbit_Location-Escaping_Energy*abs(Jump_strength*Rabbit_Location-X[i,:])+numpy.multiply(numpy.random.randn(dim),Levy(dim))
                        if objf(X2)< fitness:
                            X[i,:] = X2.copy()
                if r<0.5 and abs(Escaping_Energy)<0.5:   # Hard besiege Eq. (11) in paper
                    Jump_strength=2*(1-random.random())
                    X1=Rabbit_Location-Escaping_Energy*abs(Jump_strength*Rabbit_Location-X.mean(0))
         
                    if objf(X1)< fitness: # improved move?
                        X[i,:] = X1.copy()
                    else: # Perform levy-based short rapid dives around the rabbit
                        X2=Rabbit_Location-Escaping_Energy*abs(Jump_strength*Rabbit_Location-X.mean(0))+numpy.multiply(numpy.random.randn(dim),Levy(dim))
                        if objf(X2)< fitness:
                            X[i,:] = X2.copy()
                
        convergence_curve[t]=Rabbit_Energy
        if (t%1==0):
               print(['At iteration '+ str(t)+ ' the best fitness is '+ str(Rabbit_Energy)])
        t=t+1
    
    timerEnd=time.time()  
    #s.endTime=time.strftime("%Y-%m-%d-%H-%M-%S")
    #s.executionTime=timerEnd-timerStart
    #s.convergence=convergence_curve
    #s.optimizer="HHO"   
    #s.objfname=objf.__name__
    #s.best =Rabbit_Energy 
    #s.bestIndividual = Rabbit_Location

    #return s

def Levy(dim):
    beta=1.5
    sigma=(math.gamma(1+beta)*math.sin(math.pi*beta/2)/(math.gamma((1+beta)/2)*beta*2**((beta-1)/2)))**(1/beta) 
    u= 0.01*numpy.random.randn(dim)*sigma
    v = numpy.random.randn(dim)
    zz = numpy.power(numpy.absolute(v),(1/beta))
    step = numpy.divide(u,zz)
    return step

# %%
tic = time.time()
#bounds=[(-3,3),(-3,3)]  # input bounds [(x1_min,x1_max),(x2_min,x2_max)...]
HHO(func1,lb=-3,ub=3,dim=2,SearchAgents_no=50,Max_iter=500)
toc = time.time()
print(toc -tic)


#def HHO(objf,lb,ub,dim,SearchAgents_no,Max_iter):

    #dim=30
    #SearchAgents_no=50
    #lb=-100
    #ub=100
    #Max_iter=500
# Out:
# HHO is now tackling  "func1"
# ['At iteration 0 the best fitness is -3.657485194224055']
# ['At iteration 1 the best fitness is -4.2048176417937775']
# ['At iteration 2 the best fitness is -5.383460527737745']
# ['At iteration 3 the best fitness is -5.445184683108635']
# ['At iteration 4 the best fitness is -6.0213543408529535']
# ['At iteration 5 the best fitness is -6.242639558167091']
# ['At iteration 6 the best fitness is -6.281695771604373']
# ['At iteration 7 the best fitness is -6.281695771604373']
# ['At iteration 8 the best fitness is -6.281695771604373']
# ['At iteration 9 the best fitness is -6.328623626499423']
# ['At iteration 10 the best fitness is -6.350158463187557']
# ['At iteration 11 the best fitness is -6.383801418272474']
# ['At iteration 12 the best fitness is -6.4379267278608925']
# ['At iteration 13 the best fitness is -6.438686707798468']
# ['At iteration 14 the best fitness is -6.463437075176943']
# ['At iteration 15 the best fitness is -6.543169869817303']
# ...
